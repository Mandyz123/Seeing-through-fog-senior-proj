# %%
# KULLBACK LIEBLER LOSS PLOT 

import matplotlib.pyplot as plt

# define the list of loss values for each epoch

# 8,000 traffic dataset 8 epoch 
loss1 = [0.1354, 0.0709, 0.0630, 0.0564, 0.0510, 0.0472, 0.0472, 0.0397]

# 8,000 traffic dataset, 6 epoch 
#loss2 = [0.1448, 0.0711, 0.0614, 0.0532, 0.0469, 0.0415]

# 13670 animal dataset , 6 epoch 
loss3 = [0.1908, 0.1240, 0.1104, 0.0986, 0.0928, 0.0858]

# video dataset 
loss4 = [0.1443, 0.0641, 0.0515, 0.0447, 0.0389, 0.0346]

# 800 traffict dataset 8 epoch 
loss5 = [0.4655, 0.1824, 0.1337, 0.1142, 0.1062, 0.1010, 0.0984,0.0877]

# 8000 art dataset 8 epoch 

loss6 = [0.2674, 0.1643, 0.1269, 0.1110,  0.0983, 0.0925, 0.0851, 0.0811]

# 8000 arts dataset 4 epoch 

#loss7 = [0.2686, 0.1647, 0.1285, 0.1132]

# 10064 art dataset 4 epoch 
loss8 = [0.2590, 0.1537, 0.1190, 0.1031]

#10064 art dataset 8 epoch     

loss9 = [0.0923, 0.0852, 0.0815, 0.0742, 0.0703, 0.0666, 0.0638, 0.0599]

# define the x-axis values (epochs)
epochs1 = range(1, len(loss1) + 1)
#epochs2 = range(1, len(loss2) + 1)
epochs3 = range(1, len(loss3) + 1)
epochs4 = range(1, len(loss4) + 1)
epochs5 = range(1, len(loss5) + 1)
epochs6 = range(1, len(loss6) + 1)
#epochs7 = range(1, len(loss7) + 1)
epochs8 = range(1, len(loss8) + 1)
epochs9 = range(1, len(loss9) + 1)


# plot the loss values over the epochs
plt.plot(epochs1, loss1, 'b-o', label='8,000 Traffic Dataset-50cm Diffuser')
#plt.plot(epochs2, loss2, 'r-o', label='8,000 Traffic Dataset')
plt.plot(epochs3, loss3, 'g-o', label='13,670 Animal Dataset-12 inch fog tank')
plt.plot(epochs4, loss4, 'c-o', label='12,180 Video Dataset-12 inch fog tank')
plt.plot(epochs5, loss5, 'k-o', label='800 Traffic Dataset-20cm Diffuser')
plt.plot(epochs6, loss6,  marker='o',linestyle='-', color='#EE3B3B', label='8,000 Art Dataset-22cm Diffuser')
#plt.plot(epochs7, loss7,  marker='o',linestyle='-', color='#B23AEE', label='8,000 Art Dataset')
plt.plot(epochs8, loss8,  marker='o',linestyle='-', color='#B23AEE', label='10,064 Art Dataset-22cm Diffuser')
plt.plot(epochs9, loss9,  marker='o',linestyle='-', color='#EEA2AD', label='10,064 Art Dataset-22cm Diffuser')
plt.title('Kullback Leibler Training Loss over Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.ylim(0, 0.6)
plt.show()

# %%
# SSIM LOSS PLOT 
import matplotlib.pyplot as plt


# define the list of loss values for each epoch

# 800 Traffic Dataset 6 epoch 
loss1 = [0.4087, 0.3897, 0.3730, 0.3557, 0.3519, 0.3344]

# 8,000 Traffic Dataset 6 epoch 
loss2 = [0.5154, 0.4539, 0.4443, 0.4299, 0.4226, 0.4109]

# 8,000 Traffic Dataset 8 epoch 
loss3 = [0.3966, 0.3804, 0.3585, 0.3352, 0.3124, 0.2926, 0.2752, 0.2588]

# 13,670 Animal Dataset 6 epoch  
loss4 = [0.2677, 0.2175, 0.2021, 0.1860, 0.1662, 0.1480, 0.1417, 0.1751]




# define the x-axis values (epochs)

epochs1 = range(1, len(loss1) + 1)
epochs2 = range(1, len(loss2) + 1)
epochs3 = range(1, len(loss3) + 1)
epochs4 = range(1, len(loss4) + 1)



# plot the loss values over the epochs
plt.plot(epochs1, loss1, 'b-o', label='800 Traffic Dataset')
plt.plot(epochs2, loss2, 'r-o', label='8,000 Traffic Dataset')
plt.plot(epochs3, loss3, 'g-o', label='8,000 Traffic Dataset')
plt.plot(epochs4, loss4, 'k-o', label='13,670 Animal Dataset')
plt.title('SSIM Training Loss over Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# set the y-axis range
plt.ylim(0, 0.6)

plt.show()
